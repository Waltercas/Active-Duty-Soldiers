# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
ad_marital_status = pd.read_excel ('Data/AD-by-marital-status.xls')

# %%
ad_marital_status = ad_marital_status

# %%
enlisted_df = ad_marital_status[:9]

# %%
officer_df = ad_marital_status[10:21]

# %%
warrant_df = ad_marital_status[21:27]

# %%
enlisted_df
# Out:
#   Pay Grade  Single Male  Single Female  Single Total  Single Parent Male  \
# 0       E-1        31229           5717         36946                 563
# 1       E-2        53094           8388         61482                1457
# 2       E-3       131091          21019        152110                4264
# 3       E-4       112710          16381        129091                9491
# 4       E-5        57989          11021         69010               10937
# 5       E-6        19125           4654         23779               10369
# 6       E-7         5446           1913          7359                6530
# 7       E-8         1009            438          1447                1786
# 8       E-9          381            202           583                 579
#
#    Single Parent Female  Single Parent Total  Joint Service Marriage Male  \
# 0                   122                  685                          139
# 1                   275                 1732                          438
# 2                  1920                 6184                         3579
# 3                  4662                14153                         8661
# 4                  6576                17513                        12459
# 5                  4962                15331                         8474
# 6                  2585                 9115                         5065
# 7                   513                 2299                         1423
# 8                   144                  723                          458
#
#    Joint Service Marriage Female  Joint Service Marriage Total  \
# 0                            141                           280
# 1                            579                          1017
# 2                           4902                          8481
# 3                           9778                         18439
# 4                          11117                         23576
# 5                           6961                         15435
# 6                           3291                          8356
# 7                            651                          2074
# 8                            150                           608
#
#    Civilian Married Male  Civilian Married Female  Civilian Married Total  \
# 0                   5060                      719                    5779
# 1                  12483                     1682                   14165
# 2                  54795                     6641                   61436
# 3                 105556                     9961                  115517
# 4                 130944                     8592                  139536
# 5                 110322                     5827                  116149
# 6                  70001                     3206                   73207
# 7                  21079                      820                   21899
# 8                   8215                      291                    8506
#
#    Total Male  Total Female  Grand Total
# 0       36991          6699        43690
# 1       67472         10924        78396
# 2      193729         34482       228211
# 3      236418         40782       277200
# 4      212329         37306       249635
# 5      148290         22404       170694
# 6       87042         10995        98037
# 7       25297          2422        27719
# 8        9633           787        10420

# %%
enlisted_df2 = enlisted_df.drop(columns=['Single Total', 'Joint Service Marriage Total', 'Single Parent Total', 'Civilian Married Total', 'Grand Total','Total Male', 'Total Female'])

# %%
enlisted_df2.plot(figsize=(12,8), )
# Out:
# <AxesSubplot:>

# %%
enlisted_df3 = enlisted_df.drop(columns=['Single Male', 'Single Female', 'Joint Service Marriage Male', 'Joint Service Marriage Female','Single Parent Male','Single Parent Female', 'Civilian Married Male','Civilian Married Female', 'Grand Total','Total Male', 'Total Female'])

# %%
enlisted_df3.plot(figsize=(12,8))
enlisted_df3
# Out:
#   Pay Grade  Single Total  Single Parent Total  Joint Service Marriage Total  \
# 0       E-1         36946                  685                           280
# 1       E-2         61482                 1732                          1017
# 2       E-3        152110                 6184                          8481
# 3       E-4        129091                14153                         18439
# 4       E-5         69010                17513                         23576
# 5       E-6         23779                15331                         15435
# 6       E-7          7359                 9115                          8356
# 7       E-8          1447                 2299                          2074
# 8       E-9           583                  723                           608
#
#    Civilian Married Total
# 0                    5779
# 1                   14165
# 2                   61436
# 3                  115517
# 4                  139536
# 5                  116149
# 6                   73207
# 7                   21899
# 8                    8506

# %%
x = enlisted_df3['Pay Grade']
y = enlisted_df3['Single Total']

# %%
fig, ax = plt.subplots(figsize=(16,8)) 
ax.plot(x, enlisted_df3['Single Total'], label = 'Single Total') 
ax.plot(x, enlisted_df3['Single Parent Total'],label = 'Single Parent Total')
ax.plot(x, enlisted_df3['Joint Service Marriage Total'],label = 'Joint Service Marriage Total')
ax.plot(x, enlisted_df3['Civilian Married Total'],label = 'Civilian Marriage Total')
plt.legend(loc="upper right")
plt.xlabel('Enlisted Rank')
plt.ylabel('Number of Service Members')
plt.rcParams.update({'font.size': 18})
plt.grid()

# %%
# Out:
#   Pay Grade
# 0       E-1
# 1       E-2
# 2       E-3
# 3       E-4
# 4       E-5
# 5       E-6
# 6       E-7
# 7       E-8
# 8       E-9
