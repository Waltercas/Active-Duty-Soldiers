# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
ad_marital_status = pd.read_excel ('Data/AD-by-marital-status.xls')

# %%
ad_marital_status = ad_marital_status.set_index('Pay Grade')

# %%
enlisted_df = ad_marital_status[:9]

# %%
officer_df = ad_marital_status[10:21]

# %%
warrant_df = ad_marital_status[21:27]

# %%
enlisted_df
# Out:
#                 Single Male  Single Female  Single Total  Single Parent Male  \
# Pay Grade
# E-1                   31229           5717         36946                 563
# E-2                   53094           8388         61482                1457
# E-3                  131091          21019        152110                4264
# E-4                  112710          16381        129091                9491
# E-5                   57989          11021         69010               10937
# E-6                   19125           4654         23779               10369
# E-7                    5446           1913          7359                6530
# E-8                    1009            438          1447                1786
# E-9                     381            202           583                 579
# TOTAL ENLISTED       412074          69733        481807               45976
#
#                 Single Parent Female  Single Parent Total  \
# Pay Grade
# E-1                              122                  685
# E-2                              275                 1732
# E-3                             1920                 6184
# E-4                             4662                14153
# E-5                             6576                17513
# E-6                             4962                15331
# E-7                             2585                 9115
# E-8                              513                 2299
# E-9                              144                  723
# TOTAL ENLISTED                 21759                67735
#
#                 Joint Service Marriage Male  Joint Service Marriage Female  \
# Pay Grade
# E-1                                     139                            141
# E-2                                     438                            579
# E-3                                    3579                           4902
# E-4                                    8661                           9778
# E-5                                   12459                          11117
# E-6                                    8474                           6961
# E-7                                    5065                           3291
# E-8                                    1423                            651
# E-9                                     458                            150
# TOTAL ENLISTED                        40696                          37570
#
#                 Joint Service Marriage Total  Civilian Married Male  \
# Pay Grade
# E-1                                      280                   5060
# E-2                                     1017                  12483
# E-3                                     8481                  54795
# E-4                                    18439                 105556
# E-5                                    23576                 130944
# E-6                                    15435                 110322
# E-7                                     8356                  70001
# E-8                                     2074                  21079
# E-9                                      608                   8215
# TOTAL ENLISTED                         78266                 518455
#
#                 Civilian Married Female  Civilian Married Total  Total Male  \
# Pay Grade
# E-1                                 719                    5779       36991
# E-2                                1682                   14165       67472
# E-3                                6641                   61436      193729
# E-4                                9961                  115517      236418
# E-5                                8592                  139536      212329
# E-6                                5827                  116149      148290
# E-7                                3206                   73207       87042
# E-8                                 820                   21899       25297
# E-9                                 291                    8506        9633
# TOTAL ENLISTED                    37739                  556194     1017201
#
#                 Total Female  Grand Total
# Pay Grade
# E-1                     6699        43690
# E-2                    10924        78396
# E-3                    34482       228211
# E-4                    40782       277200
# E-5                    37306       249635
# E-6                    22404       170694
# E-7                    10995        98037
# E-8                     2422        27719
# E-9                      787        10420
# TOTAL ENLISTED        166801      1184002

# %%
enlisted_df2 = enlisted_df.drop(columns=['Single Total', 'Joint Service Marriage Total', 'Single Parent Total', 'Civilian Married Total', 'Grand Total','Total Male', 'Total Female'])

# %%
enlisted_df2.plot()
# Out:
# <AxesSubplot:xlabel='Pay Grade'>
